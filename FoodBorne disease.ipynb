# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', '.Rhistory', '01-Intro_to_IBM_Cognos_Analytics_admin.pps', '0793999_lab7.xlsx', '123', '2.1.5.5-IM-Data-Server-Manager-win64(1).zip', '53041312-ontario-drivers-handbook.pdf', '5_6217592574077568864.ipynb', '8-Transaction Management- Intro(1).pdf', '9 Transactions Concurrency Control(1).pdf', 'All sections Data.xlsx', 'AllServiceRequests_2021.csv', 'All_Streaming_Shows (1).csv', 'ames(1).csv', 'amzn_2012-7-31_2017-6-30 (1).csv', 'amzn_2012-7-31_2017-6-30.csv', 'Anaconda3-2021.11-Windows-x86_64.exe', 'Anan Resume PT.docx', 'AnyDesk.exe', 'ApacheDirectoryStudio-win32-1.5.3.v20100330(1)', 'ApacheDirectoryStudio-win32-1.5.3.v20100330(1).zip', 'App Usage Survey.xlsx', 'appdata.csv', 'Application Package [Authentication Successful].pdf', 'archive', 'archive (1).zip', 'archive (3).zip', 'archive.zip', 'Assessment Change Student Notification.docx', 'Assignment 3(0793770).xlsx', 'Assignment_4_0785748.xlsx', 'AWS_Resume.docx', 'BB_Resume.docx', 'Binomial-wk8.xlsx', 'Calcu
# ...

# %%
df = pd.read_csv("outbreaks.csv")
df
# Out:
#        Year     Month       State                               Location  \
# 0      1998   January  California                             Restaurant
# 1      1998   January  California                                    NaN
# 2      1998   January  California                             Restaurant
# 3      1998   January  California                             Restaurant
# 4      1998   January  California                 Private Home/Residence
# ...     ...       ...         ...                                    ...
# 19114  2015  December   Wisconsin                             Restaurant
# 19115  2015  December   Wisconsin                 Private Home/Residence
# 19116  2015  December   Wisconsin  Nursing Home/Assisted Living Facility
# 19117  2015  December   Wisconsin                   Fast Food Restaurant
# 19118  2015  December     Wyoming                                    NaN
#
#                                     Food Ingredient                 Species  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19119 entries, 0 to 19118
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               19119 non-null  int64
#  1   Month              19119 non-null  object
#  2   State              19119 non-null  object
#  3   Location           16953 non-null  object
#  4   Food               10156 non-null  object
#  5   Ingredient         1876 non-null   object
#  6   Species            12500 non-null  object
#  7   Serotype/Genotype  3907 non-null   object
#  8   Status             12500 non-null  object
#  9   Illnesses          19119 non-null  int64
#  10  Hospitalizations   15494 non-null  float64
#  11  Fatalities         15518 non-null  float64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 1.8+ MB

# %%
df.head()
# Out:
#    Year    Month       State                Location  \
# 0  1998  January  California              Restaurant
# 1  1998  January  California                     NaN
# 2  1998  January  California              Restaurant
# 3  1998  January  California              Restaurant
# 4  1998  January  California  Private Home/Residence
#
#                                 Food Ingredient              Species  \
# 0                                NaN        NaN                  NaN
# 1                            Custard        NaN                  NaN
# 2                                NaN        NaN                  NaN
# 3                          Fish, Ahi        NaN      Scombroid toxin
# 4  Lasagna, Unspecified; Eggs, Other        NaN  Salmonella enterica
#
#   Serotype/Genotype     Status  Illnesses  Hospitalizations  Fatalities
# 0               NaN        NaN         20               0.0         0.0
# 1               NaN        NaN        112               0.0         0.0
# ...

# %%
df.tail()
# Out:
#        Year     Month      State                               Location  \
# 19114  2015  December  Wisconsin                             Restaurant
# 19115  2015  December  Wisconsin                 Private Home/Residence
# 19116  2015  December  Wisconsin  Nursing Home/Assisted Living Facility
# 19117  2015  December  Wisconsin                   Fast Food Restaurant
# 19118  2015  December    Wyoming                                    NaN
#
#         Food Ingredient                 Species       Serotype/Genotype  \
# 19114    NaN        NaN  Norovirus genogroup II                  GII_14
# 19115  Salsa        NaN  Norovirus genogroup II                   GII_2
# 19116    NaN        NaN  Norovirus genogroup II  GII_17 Kawasaki (2014)
# 19117    NaN        NaN  Norovirus genogroup II                   GII_2
# 19118    NaN        NaN                     NaN                     NaN
#
#           Status  Illnesses  Hospitalizations  Fatalities
# ...

# %%
df.isnull().sum()
# Out:
# Year                     0
# Month                    0
# State                    0
# Location              2166
# Food                  8963
# Ingredient           17243
# Species               6619
# Serotype/Genotype    15212
# Status                6619
# Illnesses                0
# Hospitalizations      3625
# Fatalities            3601
# dtype: int64

# %%
df.shape
# Out:
# (19119, 12)

# %%
df.drop(['Hospitalizations','Fatalities','Serotype/Genotype'], axis=1, inplace=True)
df
# Out:
#        Year     Month       State                               Location  \
# 0      1998   January  California                             Restaurant
# 1      1998   January  California                                    NaN
# 2      1998   January  California                             Restaurant
# 3      1998   January  California                             Restaurant
# 4      1998   January  California                 Private Home/Residence
# ...     ...       ...         ...                                    ...
# 19114  2015  December   Wisconsin                             Restaurant
# 19115  2015  December   Wisconsin                 Private Home/Residence
# 19116  2015  December   Wisconsin  Nursing Home/Assisted Living Facility
# 19117  2015  December   Wisconsin                   Fast Food Restaurant
# 19118  2015  December     Wyoming                                    NaN
#
#                                     Food Ingredient                 Species  \
# ...

# %%
df.fillna(0)
# Out:
#        Year     Month       State                               Location  \
# 0      1998   January  California                             Restaurant
# 1      1998   January  California                                      0
# 2      1998   January  California                             Restaurant
# 3      1998   January  California                             Restaurant
# 4      1998   January  California                 Private Home/Residence
# ...     ...       ...         ...                                    ...
# 19114  2015  December   Wisconsin                             Restaurant
# 19115  2015  December   Wisconsin                 Private Home/Residence
# 19116  2015  December   Wisconsin  Nursing Home/Assisted Living Facility
# 19117  2015  December   Wisconsin                   Fast Food Restaurant
# 19118  2015  December     Wyoming                                      0
#
#                                     Food Ingredient                 Species  \
# ...

# %%
df.to_csv
# Out:
# <bound method NDFrame.to_csv of        Year     Month       State                               Location  \
# 0      1998   January  California                             Restaurant
# 1      1998   January  California                                    NaN
# 2      1998   January  California                             Restaurant
# 3      1998   January  California                             Restaurant
# 4      1998   January  California                 Private Home/Residence
# ...     ...       ...         ...                                    ...
# 19114  2015  December   Wisconsin                             Restaurant
# 19115  2015  December   Wisconsin                 Private Home/Residence
# 19116  2015  December   Wisconsin  Nursing Home/Assisted Living Facility
# 19117  2015  December   Wisconsin                   Fast Food Restaurant
# 19118  2015  December     Wyoming                                    NaN
#
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\puroh\\Downloads'

# %%
os.chdir("C:\\Users\\puroh\\Downloads")

# %%
df.to_csv('outbreaks_Cleaned.csv', index=False)
